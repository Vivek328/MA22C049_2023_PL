# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_US.csv'

# %%
df = pd.read_csv(url)
df.head()
# Out:
#         UID iso2 iso3  code3    FIPS   Admin2 Province_State Country_Region  \
# 0  84001001   US  USA    840  1001.0  Autauga        Alabama             US
# 1  84001003   US  USA    840  1003.0  Baldwin        Alabama             US
# 2  84001005   US  USA    840  1005.0  Barbour        Alabama             US
# 3  84001007   US  USA    840  1007.0     Bibb        Alabama             US
# 4  84001009   US  USA    840  1009.0   Blount        Alabama             US
#
#          Lat      Long_  ... 2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  3/5/23  \
# 0  32.539527 -86.644082  ...   19732   19759   19759   19759   19759   19759
# 1  30.727750 -87.722071  ...   69641   69767   69767   69767   69767   69767
# 2  31.868263 -85.387129  ...    7451    7474    7474    7474    7474    7474
# 3  32.996421 -87.125115  ...    8067    8087    8087    8087    8087    8087
# 4  33.982109 -86.567906  ...   18616   18673   18673   18673   18673   18673
#
#    3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %%
#df.info()

# %%
#df.rename(columns={"Date":"date","Province_State":"state","Country/Region":"country","Lat":"lat",
# "Long":"long","Confirmed":"confirmed","Deaths":"deaths","Recovered":"recovered"},inplace=True)

# %%
#df

# %%
if 'df' in locals() and 'Province_State' in df.columns:
    states = ['Oregon', 'Washington', 'California']
    state_data = df[df['Province_State'].isin(states)]
    num_records = len(state_data)

    print(f"Number of records in Oregon, Washington, and California: {num_records}")
else:
    print("The 'df' DataFrame or 'Province_State' column does not exist.")
# Out:
# Number of records in Oregon, Washington, and California: 139

# %%
# Drop un necessary columns  in the DataFrame
columns_to_drop = ['UID', 'iso2', 'iso3', 'code3', 'FIPS', 'Admin2', 'Country_Region', 'Lat', 'Long_', 'Combined_Key']
state_data = state_data.drop(columns=[col for col in columns_to_drop if col in state_data.columns])
state_data.head()
# Out:
#     Province_State  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# 197     California        0        0        0        0        0        0
# 198     California        0        0        0        0        0        0
# 199     California        0        0        0        0        0        0
# 200     California        0        0        0        0        0        0
# 201     California        0        0        0        0        0        0
#
#      1/28/20  1/29/20  1/30/20  ...  2/28/23  3/1/23  3/2/23  3/3/23  3/4/23  \
# 197        0        0        0  ...   401161  401161  401161  401161  401161
# 198        0        0        0  ...      143     143     143     143     143
# 199        0        0        0  ...    11540   11540   11540   11540   11540
# 200        0        0        0  ...    51916   51916   51916   51916   51916
# 201        0        0        0  ...     9634    9634    9634    9634    9634
#
#      3/5/23  3/6/23  3/7/23  3/8/23  3/9/23
# ...

# %%
state_data=state_data.groupby('Province_State').sum().T

# %%
# Plot the data for California in black with a solid line
state_data['California'].plot(color="black", linestyle='-', label='California')

# Plot the data for Washington in blue with a dashed line
state_data['Washington'].plot(color="blue", linestyle='--', label='Washington')

# Plot the data for Oregon in green with a dotted line
state_data['Oregon'].plot(color="green", linestyle=':', label='Oregon')

# Customize the labels and legend
plt.xlabel('Date')
plt.ylabel('Cases')
plt.title('COVID-19 Cases in Different States')
plt.legend()

# Show the plot
plt.show()
